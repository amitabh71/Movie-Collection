# %%
import pandas as pd

# %%
movie_data=pd.read_csv('/Users/amitabhsinha/Desktop/Amitabh Sinha/Deep Learning/data/Movie_collection_Independent.csv', header=0)

# %%
movie_data
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
movie_data.head()
# Out:
#    Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0           20.1264               59.62               0.462  36524.125
# 1           20.5462               69.14               0.531  35668.655
# 2           20.5458               69.14               0.531  39912.675
# 3           20.6474               59.36               0.542  38873.890
# 4           21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
import keras
# Out:
# 2024-01-17 18:37:20.822100: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf

# %%
keras.__version__
# Out:
# '2.15.0'

# %%
movie_data.describe()
# Out:
#        Marketin_expense  Production_expense  Multiplex_coverage        Budget  \
# count        506.000000          506.000000          506.000000    506.000000
# mean          92.270471           77.273557            0.445305  34911.144022
# std          172.030902           13.720706            0.115878   3903.038232
# min           20.126400           55.920000            0.129000  19781.355000
# 25%           21.640900           65.380000            0.376000  32693.952500
# 50%           25.130200           74.380000            0.462000  34488.217500
# 75%           93.541650           91.200000            0.551000  36793.542500
# max         1799.524000          110.480000            0.615000  48772.900000
#
#        Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# count    506.000000          506.000000           506.000000       506.000000
# mean     142.074901            8.014002             8.185613         8.019664
# ...

# %%
movie_target_data= pd.read_csv("/Users/amitabhsinha/Desktop/Amitabh Sinha/Deep Learning/data/Movie_collection_Target.csv",header=0)

# %%
movie_target_data.head()
# Out:
#    Collection
# 0    2.266667
# 1    2.106667
# 2    2.980000
# 3    2.893333
# 4    3.080000

# %%
from sklearn.model_selection import train_test_split

X_train_full , X_test , y_train_full , y_test =train_test_split(movie_data ,movie_target_data , random_state=42)
X_train ,X_valid ,y_train , y_valid=train_test_split(X_train_full,y_train_full, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_valid=scaler.transform(X_valid)
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (284, 19)

# %%
import numpy as np

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
X_valid.shape
# Out:
# (95, 19)

# %%
X_test.shape
# Out:
# (127, 19)

# %%
model =keras.models.Sequential(
    [keras.layers.Dense(30,activation="relu",input_shape=[19]),
     keras.layers.Dense(30,activation="relu"),
     keras.layers.Dense(1)
     
        
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 30)                600
#
#  dense_1 (Dense)             (None, 30)                930
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 1561 (6.10 KB)
# Trainable params: 1561 (6.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss="mean_squared_error",
             optimizer=keras.optimizers.SGD(lr=1e-3),
             metrics=['mae'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model_history=model.fit(X_train ,y_train,epochs=50,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 9/9 [==============================] - 1s 28ms/step - loss: 3.0137 - mae: 1.5337 - val_loss: 1.7663 - val_mae: 1.1217
# Epoch 2/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9732 - mae: 0.7921 - val_loss: 0.9926 - val_mae: 0.8053
# Epoch 3/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6392 - mae: 0.6372 - val_loss: 0.7626 - val_mae: 0.6923
# Epoch 4/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4766 - mae: 0.5467 - val_loss: 0.6259 - val_mae: 0.6195
# Epoch 5/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3712 - mae: 0.4868 - val_loss: 0.5288 - val_mae: 0.5624
# Epoch 6/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3013 - mae: 0.4410 - val_loss: 0.4656 - val_mae: 0.5227
# Epoch 7/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2520 - mae: 0.4026 - val_loss: 0.4145 - val_mae: 0.4875
# Epoch 8/50
# ...

# %%
mae_test=model.evaluate(X_test ,y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6798 - mae: 0.3636

# %%
model_history.history
# Out:
# {'loss': [3.013650417327881,
#   0.9731757044792175,
#   0.639150083065033,
#   0.47656577825546265,
#   0.37117356061935425,
#   0.30129900574684143,
#   0.2519628405570984,
#   0.21699976921081543,
#   0.1923094391822815,
#   0.17265264689922333,
#   0.1587819904088974,
#   0.1482875645160675,
#   0.13950981199741364,
#   0.13290418684482574,
#   0.12644805014133453,
#   0.12206121534109116,
#   0.11788937449455261,
#   0.11380178481340408,
#   0.11083885282278061,
#   0.10709264129400253,
#   0.10389958322048187,
#   0.10175149142742157,
#   0.09962601959705353,
#   0.09723444283008575,
#   0.09523262828588486,
#   0.09373042732477188,
#   0.09154962748289108,
#   0.0908701941370964,
#   0.08917142450809479,
#   0.08811617642641068,
#   0.08622679859399796,
#   0.08521035313606262,
#   0.08377643674612045,
#   0.08275073766708374,
#   0.08191414922475815,
#   0.08056318014860153,
#   0.07966373860836029,
#   0.07867467403411865,
#   0.07786232978105545,
#   0.07728561013936996,
# ...

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
pd.DataFrame(model_history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)

plt.show()

# %%
model_history=model.fit(X_train ,y_train,epochs=50,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0696 - mae: 0.1974 - val_loss: 0.1802 - val_mae: 0.3003
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0691 - mae: 0.1961 - val_loss: 0.1788 - val_mae: 0.2980
# Epoch 3/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0683 - mae: 0.1947 - val_loss: 0.1777 - val_mae: 0.2965
# Epoch 4/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0681 - mae: 0.1960 - val_loss: 0.1776 - val_mae: 0.2988
# Epoch 5/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0675 - mae: 0.1940 - val_loss: 0.1764 - val_mae: 0.2962
# Epoch 6/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0670 - mae: 0.1922 - val_loss: 0.1755 - val_mae: 0.2945
# Epoch 7/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0666 - mae: 0.1916 - val_loss: 0.1752 - val_mae: 0.2949
# Epoch 8/50
# ...

# %%
mae_test=model.evaluate(X_test ,y_test)
# Out:
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4509 - mae: 0.3240

# %%
model_history.history
# Out:
# {'loss': [0.06956611573696136,
#   0.06907648593187332,
#   0.06832057237625122,
#   0.06809976696968079,
#   0.06749961525201797,
#   0.06698198616504669,
#   0.06657762825489044,
#   0.06576865166425705,
#   0.06521350890398026,
#   0.06484407931566238,
#   0.06419137865304947,
#   0.0640292838215828,
#   0.06339471787214279,
#   0.06289119273424149,
#   0.062173452228307724,
#   0.061985887587070465,
#   0.06163545325398445,
#   0.06091301143169403,
#   0.06068497523665428,
#   0.05998949334025383,
#   0.059398382902145386,
#   0.05943828076124191,
#   0.05895299091935158,
#   0.05851348116993904,
#   0.05795517936348915,
#   0.0576971098780632,
#   0.05715887248516083,
#   0.05706777796149254,
#   0.05674073472619057,
#   0.05637972801923752,
#   0.055668581277132034,
#   0.05555092915892601,
#   0.05496503412723541,
#   0.05470063537359238,
#   0.0543203167617321,
#   0.0538167729973793,
#   0.053551871329545975,
#   0.053184375166893005,
#   0.05288252234458923,
# ...

# %%
pd.DataFrame(model_history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)

plt.show()

# %%
X_new=X_test[:5]

# %%
y_pred=model.predict(X_new)
print(y_pred)
print(y_test[:5])
# Out:
# 1/1 [==============================] - 0s 169ms/step
# [[2.2239065]
#  [2.4251242]
#  [2.0704918]
#  [2.3848965]
#  [1.8935251]]
#      Collection
# 173    2.240000
# 274    2.826667
# 491    1.573333
# 72     2.186667
# 452    1.740000
